# %%
using Distributed
addprocs(44);

# %%
# ### Fitting a choice model
# Blah blah blah

using pulse_input_DDM
# Out:
# ┌ Info: Recompiling stale cache file /usr/people/briandd/.julia/compiled/v1.2/pulse_input_DDM/m8WoA.ji for pulse_input_DDM [c2542da2-1f7d-11e9-2506-87691095ebb2]
# └ @ Base loading.jl:1240
# ┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
# │   exception = Required dependency Arpack [7d9fca2a-8960-54d3-9f78-7d1dccf2cb97] failed to load from a cache file.
# └ @ Base loading.jl:1025
# ┌ Warning: Replacing module `Arpack`
# └ @ Base loading.jl:931
# ┌ Warning: Replacing docs for `FileIO.filename :: Tuple{Any}` in module `FileIO`
# └ @ Base.Docs docs/Docs.jl:223
# ┌ Warning: Replacing docs for `FileIO.file_extension :: Tuple{Any}` in module `FileIO`
# └ @ Base.Docs docs/Docs.jl:223
#       From worker 14:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 14:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 14:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 11:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 11:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 11:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 5:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 5:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 5:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 44:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 44:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 44:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 34:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 34:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 34:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 41:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 41:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 41:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 19:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 19:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 19:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 29:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 29:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 29:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 2:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 2:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 2:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 35:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 35:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 35:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 22:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 22:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 22:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 33:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 33:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 33:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 39:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 39:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 39:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 28:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 28:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 28:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 16:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 16:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 16:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 32:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 32:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 32:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 40:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 40:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 40:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 36:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 36:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 36:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 26:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 26:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 26:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 15:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 15:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 15:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 3:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 3:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 3:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 8:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 8:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 8:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 38:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 38:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 38:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 10:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 10:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 10:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 6:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 6:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 6:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 24:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 24:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 24:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 42:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 42:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 42:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 27:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 27:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 27:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 20:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 20:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 20:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 17:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 17:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 17:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 30:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 30:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 30:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 9:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 9:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 9:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 13:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 13:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 13:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 37:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 37:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 37:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 18:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 18:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 18:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 25:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 25:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 25:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 4:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 4:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 4:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 31:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 31:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 31:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 7:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 7:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 7:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 23:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 23:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 23:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 21:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 21:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 21:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 45:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 45:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 45:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 12:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 12:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 12:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 43:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 43:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 43:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 16:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa]
#       From worker 16:	│   exception = ArgumentError: Invalid checksum in cache file /usr/people/briandd/.julia/compiled/v1.2/Rmath/0iTqX.ji.
#       From worker 16:	└ @ Base loading.jl:1025
#       From worker 3:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa]
#       From worker 3:	│   exception = ArgumentError: Invalid checksum in cache file /usr/people/briandd/.julia/compiled/v1.2/Rmath/0iTqX.ji.
#       From worker 3:	└ @ Base loading.jl:1025
#       From worker 30:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa]
#       From worker 30:	│   exception = ArgumentError: Invalid checksum in cache file /usr/people/briandd/.julia/compiled/v1.2/Rmath/0iTqX.ji.
#       From worker 30:	└ @ Base loading.jl:1025
#       From worker 2:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa]
#       From worker 2:	│   exception = ArgumentError: Invalid checksum in cache file /usr/people/briandd/.julia/compiled/v1.2/Rmath/0iTqX.ji.
#       From worker 2:	└ @ Base loading.jl:1025
#       From worker 21:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa]
#       From worker 21:	│   exception = ArgumentError: Invalid checksum in cache file /usr/people/briandd/.julia/compiled/v1.2/Rmath/0iTqX.ji.
#       From worker 21:	└ @ Base loading.jl:1025
#       From worker 37:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa]
#       From worker 37:	│   exception = ArgumentError: Invalid checksum in cache file /usr/people/briandd/.julia/compiled/v1.2/Rmath/0iTqX.ji.
#       From worker 37:	└ @ Base loading.jl:1025
#       From worker 32:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa]
#       From worker 32:	│   exception = ArgumentError: Invalid checksum in cache file /usr/people/briandd/.julia/compiled/v1.2/Rmath/0iTqX.ji.
#       From worker 32:	└ @ Base loading.jl:1025
#       From worker 11:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c]
#       From worker 11:	│   exception = Required dependency Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa] failed to load from a cache file.
#       From worker 11:	└ @ Base loading.jl:1025
#       From worker 34:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c]
#       From worker 34:	│   exception = Required dependency Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa] failed to load from a cache file.
#       From worker 34:	└ @ Base loading.jl:1025
#       From worker 5:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c]
#       From worker 5:	│   exception = Required dependency Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa] failed to load from a cache file.
#       From worker 5:	└ @ Base loading.jl:1025
#       From worker 33:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c]
#       From worker 33:	│   exception = Required dependency Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa] failed to load from a cache file.
#       From worker 33:	└ @ Base loading.jl:1025
#       From worker 41:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c]
#       From worker 41:	│   exception = Required dependency Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa] failed to load from a cache file.
#       From worker 41:	└ @ Base loading.jl:1025
#       From worker 35:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c]
#       From worker 35:	│   exception = Required dependency Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa] failed to load from a cache file.
#       From worker 35:	└ @ Base loading.jl:1025
#       From worker 44:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c]
#       From worker 44:	│   exception = ArgumentError: Invalid checksum in cache file /usr/people/briandd/.julia/compiled/v1.2/StatsFuns/530lR.ji.
#       From worker 44:	└ @ Base loading.jl:1025
#       From worker 39:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c]
#       From worker 39:	│   exception = ArgumentError: Invalid checksum in cache file /usr/people/briandd/.julia/compiled/v1.2/StatsFuns/530lR.ji.
#       From worker 39:	└ @ Base loading.jl:1025
#       From worker 19:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c]
#       From worker 19:	│   exception = Required dependency Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa] failed to load from a cache file.
#       From worker 19:	└ @ Base loading.jl:1025
#       From worker 14:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c]
#       From worker 14:	│   exception = Required dependency Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa] failed to load from a cache file.
#       From worker 14:	└ @ Base loading.jl:1025
#       From worker 26:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c]
#       From worker 26:	│   exception = Required dependency Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa] failed to load from a cache file.
#       From worker 26:	└ @ Base loading.jl:1025
#       From worker 22:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c]
#       From worker 22:	│   exception = Required dependency Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa] failed to load from a cache file.
#       From worker 22:	└ @ Base loading.jl:1025
#       From worker 25:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c]
#       From worker 25:	│   exception = Required dependency Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa] failed to load from a cache file.
#       From worker 25:	└ @ Base loading.jl:1025
#       From worker 29:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c]
#       From worker 29:	│   exception = Required dependency Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa] failed to load from a cache file.
#       From worker 29:	└ @ Base loading.jl:1025
#       From worker 36:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c]
#       From worker 36:	│   exception = Required dependency Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa] failed to load from a cache file.
#       From worker 36:	└ @ Base loading.jl:1025
#       From worker 17:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c]
#       From worker 17:	│   exception = Required dependency Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa] failed to load from a cache file.
#       From worker 17:	└ @ Base loading.jl:1025
#       From worker 38:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c]
#       From worker 38:	│   exception = Required dependency Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa] failed to load from a cache file.
#       From worker 38:	└ @ Base loading.jl:1025
#       From worker 9:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c]
#       From worker 9:	│   exception = Required dependency Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa] failed to load from a cache file.
#       From worker 9:	└ @ Base loading.jl:1025
#       From worker 28:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c]
#       From worker 28:	│   exception = Required dependency Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa] failed to load from a cache file.
#       From worker 28:	└ @ Base loading.jl:1025
#       From worker 40:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c]
#       From worker 40:	│   exception = Required dependency Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa] failed to load from a cache file.
#       From worker 40:	└ @ Base loading.jl:1025
#       From worker 18:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c]
#       From worker 18:	│   exception = Required dependency Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa] failed to load from a cache file.
#       From worker 18:	└ @ Base loading.jl:1025
#       From worker 10:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c]
#       From worker 10:	│   exception = Required dependency Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa] failed to load from a cache file.
#       From worker 10:	└ @ Base loading.jl:1025
#       From worker 15:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c]
#       From worker 15:	│   exception = Required dependency Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa] failed to load from a cache file.
#       From worker 15:	└ @ Base loading.jl:1025
#       From worker 24:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c]
#       From worker 24:	│   exception = Required dependency Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa] failed to load from a cache file.
#       From worker 24:	└ @ Base loading.jl:1025
#       From worker 27:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c]
#       From worker 27:	│   exception = Required dependency Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa] failed to load from a cache file.
#       From worker 27:	└ @ Base loading.jl:1025
#       From worker 6:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c]
#       From worker 6:	│   exception = Invalid input in module list: expected CRC32c.
#       From worker 6:	└ @ Base loading.jl:1025
#       From worker 34:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 34:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 34:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 11:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 11:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 11:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 5:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 5:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 5:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 33:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 33:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 33:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 35:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 35:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 35:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 19:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 19:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 19:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 44:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 44:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 44:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 41:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 41:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 41:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 26:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 26:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 26:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 39:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 39:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 39:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 22:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 22:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 22:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 14:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 14:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 14:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 36:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 36:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 36:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 29:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 29:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 29:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 17:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 17:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 17:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 28:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 28:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 28:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 25:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 25:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 25:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 10:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 10:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 10:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 27:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 27:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 27:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 9:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 9:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 9:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 15:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 15:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 15:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 38:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 38:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 38:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 18:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 18:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 18:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 40:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 40:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 40:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 24:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 24:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 24:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 6:	┌ Warning: `lgamma(x::Real)` is deprecated, use `(logabsgamma(x))[1]` instead.
#       From worker 6:	│   caller = lstirling_asym(::BigFloat) at misc.jl:56
#       From worker 6:	└ @ StatsFuns ~/.julia/packages/StatsFuns/2QE7p/src/misc.jl:56
#       From worker 45:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for QuadGK [1fd47b50-473d-5c70-9696-f719f8f3bcdc]
#       From worker 45:	│   exception = ArgumentError: Invalid checksum in cache file /usr/people/briandd/.julia/compiled/v1.2/QuadGK/hq5Ol.ji.
#       From worker 45:	└ @ Base loading.jl:1025
#       From worker 31:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for QuadGK [1fd47b50-473d-5c70-9696-f719f8f3bcdc]
#       From worker 31:	│   exception = ArgumentError: Invalid checksum in cache file /usr/people/briandd/.julia/compiled/v1.2/QuadGK/hq5Ol.ji.
#       From worker 31:	└ @ Base loading.jl:1025
#       From worker 26:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for QuadGK [1fd47b50-473d-5c70-9696-f719f8f3bcdc]
#       From worker 26:	│   exception = ArgumentError: Invalid checksum in cache file /usr/people/briandd/.julia/compiled/v1.2/QuadGK/hq5Ol.ji.
#       From worker 26:	└ @ Base loading.jl:1025
#       From worker 23:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 23:	│   exception = ArgumentError: Invalid checksum in cache file /usr/people/briandd/.julia/compiled/v1.2/Distributions/xILW0.ji.
#       From worker 23:	└ @ Base loading.jl:1025
#       From worker 7:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 7:	│   exception = Required dependency StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c] failed to load from a cache file.
#       From worker 7:	└ @ Base loading.jl:1025
#       From worker 42:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 42:	│   exception = Required dependency StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c] failed to load from a cache file.
#       From worker 42:	└ @ Base loading.jl:1025
#       From worker 4:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 4:	│   exception = Required dependency StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c] failed to load from a cache file.
#       From worker 4:	└ @ Base loading.jl:1025
#       From worker 8:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 8:	│   exception = Required dependency StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c] failed to load from a cache file.
#       From worker 8:	└ @ Base loading.jl:1025
#       From worker 12:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 12:	│   exception = Required dependency StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c] failed to load from a cache file.
#       From worker 12:	└ @ Base loading.jl:1025
#       From worker 13:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 13:	│   exception = Required dependency StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c] failed to load from a cache file.
#       From worker 13:	└ @ Base loading.jl:1025
#       From worker 20:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 20:	│   exception = Required dependency StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c] failed to load from a cache file.
#       From worker 20:	└ @ Base loading.jl:1025
#       From worker 43:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 43:	│   exception = Required dependency StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c] failed to load from a cache file.
#       From worker 43:	└ @ Base loading.jl:1025
#       From worker 16:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 16:	│   exception = Required dependency StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c] failed to load from a cache file.
#       From worker 16:	└ @ Base loading.jl:1025
#       From worker 3:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 3:	│   exception = Required dependency StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c] failed to load from a cache file.
#       From worker 3:	└ @ Base loading.jl:1025
#       From worker 30:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 30:	│   exception = Required dependency StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c] failed to load from a cache file.
#       From worker 30:	└ @ Base loading.jl:1025
#       From worker 2:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 2:	│   exception = Required dependency StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c] failed to load from a cache file.
#       From worker 2:	└ @ Base loading.jl:1025
#       From worker 32:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 32:	│   exception = Required dependency QuadGK [1fd47b50-473d-5c70-9696-f719f8f3bcdc] failed to load from a cache file.
#       From worker 32:	└ @ Base loading.jl:1025
#       From worker 37:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 37:	│   exception = Required dependency QuadGK [1fd47b50-473d-5c70-9696-f719f8f3bcdc] failed to load from a cache file.
#       From worker 37:	└ @ Base loading.jl:1025
#       From worker 21:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 21:	│   exception = Required dependency QuadGK [1fd47b50-473d-5c70-9696-f719f8f3bcdc] failed to load from a cache file.
#       From worker 21:	└ @ Base loading.jl:1025
#       From worker 45:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 45:	│   exception = Required dependency StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c] failed to load from a cache file.
#       From worker 45:	└ @ Base loading.jl:1025
#       From worker 33:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 33:	│   exception = Required dependency QuadGK [1fd47b50-473d-5c70-9696-f719f8f3bcdc] failed to load from a cache file.
#       From worker 33:	└ @ Base loading.jl:1025
#       From worker 31:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 31:	│   exception = Required dependency StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c] failed to load from a cache file.
#       From worker 31:	└ @ Base loading.jl:1025
#       From worker 5:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 5:	│   exception = Required dependency QuadGK [1fd47b50-473d-5c70-9696-f719f8f3bcdc] failed to load from a cache file.
#       From worker 5:	└ @ Base loading.jl:1025
#       From worker 11:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 11:	│   exception = Required dependency QuadGK [1fd47b50-473d-5c70-9696-f719f8f3bcdc] failed to load from a cache file.
#       From worker 11:	└ @ Base loading.jl:1025
#       From worker 19:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 19:	│   exception = Required dependency QuadGK [1fd47b50-473d-5c70-9696-f719f8f3bcdc] failed to load from a cache file.
#       From worker 19:	└ @ Base loading.jl:1025
#       From worker 36:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 36:	│   exception = Required dependency QuadGK [1fd47b50-473d-5c70-9696-f719f8f3bcdc] failed to load from a cache file.
#       From worker 36:	└ @ Base loading.jl:1025
#       From worker 44:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 44:	│   exception = ArgumentError: Invalid checksum in cache file /usr/people/briandd/.julia/compiled/v1.2/Distributions/xILW0.ji.
#       From worker 44:	└ @ Base loading.jl:1025
#       From worker 34:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 34:	│   exception = Required dependency QuadGK [1fd47b50-473d-5c70-9696-f719f8f3bcdc] failed to load from a cache file.
#       From worker 34:	└ @ Base loading.jl:1025
#       From worker 28:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 28:	│   exception = ArgumentError: Invalid checksum in cache file /usr/people/briandd/.julia/compiled/v1.2/Distributions/xILW0.ji.
#       From worker 28:	└ @ Base loading.jl:1025
#       From worker 29:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 29:	│   exception = Required dependency QuadGK [1fd47b50-473d-5c70-9696-f719f8f3bcdc] failed to load from a cache file.
#       From worker 29:	└ @ Base loading.jl:1025
#       From worker 22:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 22:	│   exception = ArgumentError: Invalid checksum in cache file /usr/people/briandd/.julia/compiled/v1.2/Distributions/xILW0.ji.
#       From worker 22:	└ @ Base loading.jl:1025
#       From worker 35:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 35:	│   exception = Required dependency QuadGK [1fd47b50-473d-5c70-9696-f719f8f3bcdc] failed to load from a cache file.
#       From worker 35:	└ @ Base loading.jl:1025
#       From worker 41:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 41:	│   exception = Required dependency QuadGK [1fd47b50-473d-5c70-9696-f719f8f3bcdc] failed to load from a cache file.
#       From worker 41:	└ @ Base loading.jl:1025
#       From worker 33:	┌ Warning: Replacing module `Rmath`
#       From worker 33:	└ @ Base loading.jl:931
#       From worker 38:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 38:	│   exception = Required dependency QuadGK [1fd47b50-473d-5c70-9696-f719f8f3bcdc] failed to load from a cache file.
#       From worker 38:	└ @ Base loading.jl:1025
#       From worker 39:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 39:	│   exception = Required dependency QuadGK [1fd47b50-473d-5c70-9696-f719f8f3bcdc] failed to load from a cache file.
#       From worker 39:	└ @ Base loading.jl:1025
#       From worker 25:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 25:	│   exception = Required dependency QuadGK [1fd47b50-473d-5c70-9696-f719f8f3bcdc] failed to load from a cache file.
#       From worker 25:	└ @ Base loading.jl:1025
#       From worker 27:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 27:	│   exception = Required dependency QuadGK [1fd47b50-473d-5c70-9696-f719f8f3bcdc] failed to load from a cache file.
#       From worker 27:	└ @ Base loading.jl:1025
#       From worker 14:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 14:	│   exception = Required dependency QuadGK [1fd47b50-473d-5c70-9696-f719f8f3bcdc] failed to load from a cache file.
#       From worker 14:	└ @ Base loading.jl:1025
#       From worker 11:	┌ Warning: Replacing module `Rmath`
#       From worker 11:	└ @ Base loading.jl:931
#       From worker 24:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 24:	│   exception = Required dependency QuadGK [1fd47b50-473d-5c70-9696-f719f8f3bcdc] failed to load from a cache file.
#       From worker 24:	└ @ Base loading.jl:1025
#       From worker 5:	┌ Warning: Replacing module `Rmath`
#       From worker 5:	└ @ Base loading.jl:931
#       From worker 19:	┌ Warning: Replacing module `Rmath`
#       From worker 19:	└ @ Base loading.jl:931
#       From worker 18:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 18:	│   exception = Required dependency QuadGK [1fd47b50-473d-5c70-9696-f719f8f3bcdc] failed to load from a cache file.
#       From worker 18:	└ @ Base loading.jl:1025
#       From worker 36:	┌ Warning: Replacing module `Rmath`
#       From worker 36:	└ @ Base loading.jl:931
#       From worker 40:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 40:	│   exception = Required dependency QuadGK [1fd47b50-473d-5c70-9696-f719f8f3bcdc] failed to load from a cache file.
#       From worker 40:	└ @ Base loading.jl:1025
#       From worker 34:	┌ Warning: Replacing module `Rmath`
#       From worker 34:	└ @ Base loading.jl:931
#       From worker 9:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 9:	│   exception = Required dependency QuadGK [1fd47b50-473d-5c70-9696-f719f8f3bcdc] failed to load from a cache file.
#       From worker 9:	└ @ Base loading.jl:1025
#       From worker 17:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 17:	│   exception = Required dependency QuadGK [1fd47b50-473d-5c70-9696-f719f8f3bcdc] failed to load from a cache file.
#       From worker 17:	└ @ Base loading.jl:1025
#       From worker 29:	┌ Warning: Replacing module `Rmath`
#       From worker 29:	└ @ Base loading.jl:931
#       From worker 35:	┌ Warning: Replacing module `Rmath`
#       From worker 35:	└ @ Base loading.jl:931
#       From worker 10:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 10:	│   exception = Required dependency QuadGK [1fd47b50-473d-5c70-9696-f719f8f3bcdc] failed to load from a cache file.
#       From worker 10:	└ @ Base loading.jl:1025
#       From worker 41:	┌ Warning: Replacing module `Rmath`
#       From worker 41:	└ @ Base loading.jl:931
#       From worker 38:	┌ Warning: Replacing module `Rmath`
#       From worker 38:	└ @ Base loading.jl:931
#       From worker 39:	┌ Warning: Replacing module `Rmath`
#       From worker 39:	└ @ Base loading.jl:931
#       From worker 25:	┌ Warning: Replacing module `Rmath`
#       From worker 25:	└ @ Base loading.jl:931
#       From worker 27:	┌ Warning: Replacing module `Rmath`
#       From worker 27:	└ @ Base loading.jl:931
#       From worker 26:	┌ Warning: The call to compilecache failed to create a usable precompiled cache file for Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
#       From worker 26:	│   exception = Required dependency Arpack [7d9fca2a-8960-54d3-9f78-7d1dccf2cb97] failed to load from a cache file.
#       From worker 26:	└ @ Base loading.jl:1025
#       From worker 24:	┌ Warning: Replacing module `Rmath`
#       From worker 24:	└ @ Base loading.jl:931
#       From worker 14:	┌ Warning: Replacing module `Rmath`
#       From worker 14:	└ @ Base loading.jl:931
#       From worker 18:	┌ Warning: Replacing module `Rmath`
#       From worker 18:	└ @ Base loading.jl:931
#       From worker 40:	┌ Warning: Replacing module `Rmath`
#       From worker 40:	└ @ Base loading.jl:931
# ...
# │ - Otherwise you may need to report an issue with pulse_input_DDM
# └ Loading PositiveFactorizations into pulse_input_DDM from project dependency, future warnings for pulse_input_DDM are suppressed.
# ┌ Warning: Package pulse_input_DDM does not have PositiveFactorizations in its dependencies:
# │ - If you have pulse_input_DDM checked out for development and have
# │   added PositiveFactorizations as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with pulse_input_DDM
# └ Loading PositiveFactorizations into pulse_input_DDM from project dependency, future warnings for pulse_input_DDM are suppressed.
# ┌ Warning: Package pulse_input_DDM does not have PositiveFactorizations in its dependencies:
# │ - If you have pulse_input_DDM checked out for development and have
# │   added PositiveFactorizations as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with pulse_input_DDM
# └ Loading PositiveFactorizations into pulse_input_DDM from project dependency, future warnings for pulse_input_DDM are suppressed.
# ┌ Warning: Package pulse_input_DDM does not have PositiveFactorizations in its dependencies:
# │ - If you have pulse_input_DDM checked out for development and have
# │   added PositiveFactorizations as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with pulse_input_DDM
# └ Loading PositiveFactorizations into pulse_input_DDM from project dependency, future warnings for pulse_input_DDM are suppressed.
# ┌ Warning: Package pulse_input_DDM does not have PositiveFactorizations in its dependencies:
# │ - If you have pulse_input_DDM checked out for development and have
# │   added PositiveFactorizations as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with pulse_input_DDM
# └ Loading PositiveFactorizations into pulse_input_DDM from project dependency, future warnings for pulse_input_DDM are suppressed.
# ┌ Warning: Package pulse_input_DDM does not have PositiveFactorizations in its dependencies:
# │ - If you have pulse_input_DDM checked out for development and have
# │   added PositiveFactorizations as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with pulse_input_DDM
# └ Loading PositiveFactorizations into pulse_input_DDM from project dependency, future warnings for pulse_input_DDM are suppressed.
# ┌ Warning: Package pulse_input_DDM does not have PositiveFactorizations in its dependencies:
# │ - If you have pulse_input_DDM checked out for development and have
# │   added PositiveFactorizations as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with pulse_input_DDM
# └ Loading PositiveFactorizations into pulse_input_DDM from project dependency, future warnings for pulse_input_DDM are suppressed.
# ┌ Warning: Package pulse_input_DDM does not have PositiveFactorizations in its dependencies:
# │ - If you have pulse_input_DDM checked out for development and have
# │   added PositiveFactorizations as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with pulse_input_DDM
# └ Loading PositiveFactorizations into pulse_input_DDM from project dependency, future warnings for pulse_input_DDM are suppressed.
# ┌ Warning: Package pulse_input_DDM does not have PositiveFactorizations in its dependencies:
# │ - If you have pulse_input_DDM checked out for development and have
# │   added PositiveFactorizations as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with pulse_input_DDM
# └ Loading PositiveFactorizations into pulse_input_DDM from project dependency, future warnings for pulse_input_DDM are suppressed.
# ┌ Warning: Package pulse_input_DDM does not have PositiveFactorizations in its dependencies:
# │ - If you have pulse_input_DDM checked out for development and have
# │   added PositiveFactorizations as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with pulse_input_DDM
# └ Loading PositiveFactorizations into pulse_input_DDM from project dependency, future warnings for pulse_input_DDM are suppressed.
# ┌ Warning: Package pulse_input_DDM does not have PositiveFactorizations in its dependencies:
# │ - If you have pulse_input_DDM checked out for development and have
# │   added PositiveFactorizations as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with pulse_input_DDM
# └ Loading PositiveFactorizations into pulse_input_DDM from project dependency, future warnings for pulse_input_DDM are suppressed.
# ┌ Warning: Package pulse_input_DDM does not have PositiveFactorizations in its dependencies:
# │ - If you have pulse_input_DDM checked out for development and have
# │   added PositiveFactorizations as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with pulse_input_DDM
# └ Loading PositiveFactorizations into pulse_input_DDM from project dependency, future warnings for pulse_input_DDM are suppressed.
# ┌ Warning: Package pulse_input_DDM does not have PositiveFactorizations in its dependencies:
# │ - If you have pulse_input_DDM checked out for development and have
# │   added PositiveFactorizations as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with pulse_input_DDM
# └ Loading PositiveFactorizations into pulse_input_DDM from project dependency, future warnings for pulse_input_DDM are suppressed.
# ┌ Warning: Package pulse_input_DDM does not have PositiveFactorizations in its dependencies:
# │ - If you have pulse_input_DDM checked out for development and have
# │   added PositiveFactorizations as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with pulse_input_DDM
# └ Loading PositiveFactorizations into pulse_input_DDM from project dependency, future warnings for pulse_input_DDM are suppressed.
# ┌ Warning: Package pulse_input_DDM does not have PositiveFactorizations in its dependencies:
# │ - If you have pulse_input_DDM checked out for development and have
# │   added PositiveFactorizations as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with pulse_input_DDM
# └ Loading PositiveFactorizations into pulse_input_DDM from project dependency, future warnings for pulse_input_DDM are suppressed.
# ┌ Warning: Package pulse_input_DDM does not have PositiveFactorizations in its dependencies:
# │ - If you have pulse_input_DDM checked out for development and have
# │   added PositiveFactorizations as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with pulse_input_DDM
# └ Loading PositiveFactorizations into pulse_input_DDM from project dependency, future warnings for pulse_input_DDM are suppressed.
# ┌ Warning: Package pulse_input_DDM does not have PositiveFactorizations in its dependencies:
# │ - If you have pulse_input_DDM checked out for development and have
# │   added PositiveFactorizations as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with pulse_input_DDM
# └ Loading PositiveFactorizations into pulse_input_DDM from project dependency, future warnings for pulse_input_DDM are suppressed.
# ┌ Warning: Package pulse_input_DDM does not have PositiveFactorizations in its dependencies:
# │ - If you have pulse_input_DDM checked out for development and have
# │   added PositiveFactorizations as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with pulse_input_DDM
# └ Loading PositiveFactorizations into pulse_input_DDM from project dependency, future warnings for pulse_input_DDM are suppressed.
# ┌ Warning: Package pulse_input_DDM does not have PositiveFactorizations in its dependencies:
# │ - If you have pulse_input_DDM checked out for development and have
# │   added PositiveFactorizations as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with pulse_input_DDM
# └ Loading PositiveFactorizations into pulse_input_DDM from project dependency, future warnings for pulse_input_DDM are suppressed.
# ┌ Warning: Package pulse_input_DDM does not have PositiveFactorizations in its dependencies:
# │ - If you have pulse_input_DDM checked out for development and have
# │   added PositiveFactorizations as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with pulse_input_DDM
# └ Loading PositiveFactorizations into pulse_input_DDM from project dependency, future warnings for pulse_input_DDM are suppressed.
# ┌ Warning: Package pulse_input_DDM does not have PositiveFactorizations in its dependencies:
# │ - If you have pulse_input_DDM checked out for development and have
# │   added PositiveFactorizations as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with pulse_input_DDM
# └ Loading PositiveFactorizations into pulse_input_DDM from project dependency, future warnings for pulse_input_DDM are suppressed.
# ┌ Warning: Package pulse_input_DDM does not have PositiveFactorizations in its dependencies:
# │ - If you have pulse_input_DDM checked out for development and have
# │   added PositiveFactorizations as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with pulse_input_DDM
# └ Loading PositiveFactorizations into pulse_input_DDM from project dependency, future warnings for pulse_input_DDM are suppressed.
# ┌ Warning: Package pulse_input_DDM does not have PositiveFactorizations in its dependencies:
# │ - If you have pulse_input_DDM checked out for development and have
# │   added PositiveFactorizations as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with pulse_input_DDM
# └ Loading PositiveFactorizations into pulse_input_DDM from project dependency, future warnings for pulse_input_DDM are suppressed.
# ┌ Warning: Package pulse_input_DDM does not have PositiveFactorizations in its dependencies:
# │ - If you have pulse_input_DDM checked out for development and have
# │   added PositiveFactorizations as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with pulse_input_DDM
# └ Loading PositiveFactorizations into pulse_input_DDM from project dependency, future warnings for pulse_input_DDM are suppressed.
# ┌ Warning: Package pulse_input_DDM does not have PositiveFactorizations in its dependencies:
# │ - If you have pulse_input_DDM checked out for development and have
# │   added PositiveFactorizations as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with pulse_input_DDM
# └ Loading PositiveFactorizations into pulse_input_DDM from project dependency, future warnings for pulse_input_DDM are suppressed.
# ┌ Warning: Package pulse_input_DDM does not have PositiveFactorizations in its dependencies:
# │ - If you have pulse_input_DDM checked out for development and have
# │   added PositiveFactorizations as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with pulse_input_DDM
# └ Loading PositiveFactorizations into pulse_input_DDM from project dependency, future warnings for pulse_input_DDM are suppressed.
# ┌ Warning: Package pulse_input_DDM does not have PositiveFactorizations in its dependencies:
# │ - If you have pulse_input_DDM checked out for development and have
# │   added PositiveFactorizations as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with pulse_input_DDM
# └ Loading PositiveFactorizations into pulse_input_DDM from project dependency, future warnings for pulse_input_DDM are suppressed.
# ┌ Warning: Package pulse_input_DDM does not have PositiveFactorizations in its dependencies:
# │ - If you have pulse_input_DDM checked out for development and have
# │   added PositiveFactorizations as a dependency but haven't updated your primary
# │   environment's manifest file, try `Pkg.resolve()`.
# │ - Otherwise you may need to report an issue with pulse_input_DDM
# └ Loading PositiveFactorizations into pulse_input_DDM from project dependency, future warnings for pulse_input_DDM are suppressed.
# On worker 12:
# LoadError: SystemError: opening file "/usr/people/briandd/.julia/compiled/v1.2/Distributions/xILW0.ji": No such file or directory
# #systemerror#44 at ./error.jl:134
# systemerror at ./error.jl:134 [inlined]
# #open#311 at ./iostream.jl:289
# #open at ./none:0 [inlined]
# open at ./iostream.jl:345
# _require_from_serialized at ./loading.jl:719
# _require at ./loading.jl:1023
# require at ./loading.jl:911
# require at ./loading.jl:906
# include at ./boot.jl:328 [inlined]
# include_relative at ./loading.jl:1094
# _require at ./loading.jl:1042
# require at ./loading.jl:911
# #2 at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.2/Distributed/src/Distributed.jl:78
# #116 at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.2/Distributed/src/process_messages.jl:307
# run_work_thunk at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.2/Distributed/src/process_messages.jl:79
# run_work_thunk at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.2/Distributed/src/process_messages.jl:88
# #102 at ./task.jl:268
# in expression starting at /usr/people/briandd/Projects/pulse_input_DDM/src/pulse_input_DDM.jl:8
# #remotecall_wait#154(::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}, ::typeof(remotecall_wait), ::Function, ::Distributed.Worker) at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.2/Distributed/src/remotecall.jl:421
# remotecall_wait(::Function, ::Distributed.Worker) at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.2/Distributed/src/remotecall.jl:412
# #remotecall_wait#157(::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}, ::typeof(remotecall_wait), ::Function, ::Int64) at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.2/Distributed/src/remotecall.jl:433
# remotecall_wait at /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.2/Distributed/src/remotecall.jl:433 [inlined]
# (::getfield(Distributed, Symbol("##1#3")){Base.PkgId,Int64})() at ./task.jl:268
#
# Stacktrace:
#  [1] sync_end(::Array{Any,1}) at ./task.jl:235
#  [2] _require_callback(::Base.PkgId) at ./task.jl:254
#  [3] #invokelatest#1 at ./essentials.jl:790 [inlined]
#  [4] invokelatest at ./essentials.jl:789 [inlined]
#  [5] require(::Base.PkgId) at ./loading.jl:914
#  [6] require(::Module, ::Symbol) at ./loading.jl:906
#  [7] top-level scope at In[2]:1

# %%
# ### Geneerate some data
# Blah blah blah

θ_syn, data = synthetic_data(;ntrials=20000)

# ### Optimize stuff
# Blah blah blah

model, options = optimize(data)

# ### Compute Hessian
# Blah blah blah

H = Hessian(model)
# Out:
# UndefVarError: synthetic_data not defined
#
# Stacktrace:
#  [1] top-level scope at In[3]:1

# %%
# ### Get the CIs from the Hessian
# Blah blah blah

CI = CIs(model, H)
