# %%
using Distributed
addprocs(44);

# %%
using pulse_input_DDM, Flatten
# Out:
# ┌ Info: Recompiling stale cache file /usr/people/briandd/.julia/compiled/v1.2/pulse_input_DDM/m8WoA.ji for pulse_input_DDM [c2542da2-1f7d-11e9-2506-87691095ebb2]
# └ @ Base loading.jl:1240

# %%
θ_syn = θchoice(θz=θz(σ2_i = 1., B = 13., λ = -0.5, σ2_a = 10., σ2_s = 1.0,
    ϕ = 0.4, τ_ϕ = 0.02), bias=0.1, lapse=0.1);

# %%
_, data = synthetic_data(;θ=θ_syn, ntrials=5_000, rng=1, dt=2e-2);

# %%
n = 53
# Out:
# 53

# %%
loglikelihood(θ_syn, data)
# Out:
# -1887.3308344396905

# %%
#old code....
loglikelihood(θ_syn, data, n)
# Out:
# -1925.615111140547

# %%
using Random

fit = vcat(trues(7),falses(2),trues(2));
x0 = vcat([0.1, 15., -0.1, 20., 0.5, 0.2, 0.008,0.,0.], [0.,0.01])
lb=vcat([0., 8., -5., 0.,   0.,  0.01, 0.005, -30., -30.], [-5., 0.])
ub=vcat([2., 30., 5., 100., 2.5, 1.2,  1.,     30., 30.], [5., 1.]);

# %%
using Random

fit = vcat(trues(7),falses(2),trues(2));
x0 = vcat([0.1, 15., -0.1, 20., 0.5, 0.2, 0.008,0.,0.], [0.,0.01])
lb=vcat([0., 8., -5., 0.,   0.,  0.01, 0.005, -30., -30.], [-5., 0.])
ub=vcat([2., 30., 5., 100., 2.5, 1.2,  1.,     30., 30.], [5., 1.]);

function fit_x0(rng, fit, x0, lb, ub, data, n)

    Random.seed!(rng)
    x00 = lb + (ub - lb) .* rand(length(x0))
    x00[2] = 15.
    x00[8:9] .= 0.;

    options = choiceoptions(x0=x00, fit=fit, 
        lb=vcat([0.,  8., -5., 0.,   0.,  0.01, 0.005, -30., -30.], [-5., 0.]),
        ub=vcat([30., 32., 5., 200., 5.,  1.2,  1.,     30.,  30.],  [5., 1.]))

    model, output = optimize(data, options, n; f_tol=1e-9, extended_trace=true, show_trace=false, scaled=false)
    
end
# Out:
# fit_x0 (generic function with 1 method)

# %%
output = map(rng-> fit_x0(rng, fit, x0, lb, ub, data, n), 1:4)
traces = map(y-> hcat(map(x-> x.metadata["x"], y[2].trace)...), output)
# Out:
# optimization complete. converged: true
#
# optimization complete. converged: true
#
# optimization complete. converged: true
#
# optimization complete. converged: true
# 4-element Array{Array{Float64,2},1}:
#  [0.47206669132409385 0.46231316926969923 … 29.99999729953556 29.999999554662867; 15.0 14.992644604902193 … 8.750023386062008 8.75002339656498; … ; 4.8666636689879965 4.866448807407566 … 0.005387577813766898 0.005387577813766898; 0.5557510873245723 0.5557379715813772 … 0.49984921931542425 0.49984921931542425]
#  [0.7335928248798487 0.7335042791671761 … 29.999998257890905 29.99999979735094; 15.0 14.99970759683094 … 8.749816679009216 8.749816674292957; … ; 1.8956654998062161 1.8956607811378094 … -2.5182052548528644e-6 -2.518205254852864e-6; 0.14383562117576143 0.14398973064507073 … 0.49987914324237553 0.49987914324237553]
#  [1.623396809991723 1.623306896842189 … 29.999998262695467 29.999999267916134; 15.0 14.999995264571576 … 8.749647544608248 8.749647566324198; … ; 0.572251384524507 0.5722513205638353 … -0.03302491046344011 -0.0330249104634401; 0.4644219211852372 0.464422315630559 … 0.5000472522966228 0.5000472522966228]
#  [1.360158471871482 1.3599993781284894 … 29.99999780745037 29.999999620252435; 15.0 14.999992936620496 … 8.74957833387647 8.749578384925028; … ; 2.3238037955842117 2.3238031807591857 … -0.1358041098571966 -0.13580410985719657; 0.3888589512567495 0.38886137645734703 … 0.49999999848833293 0.49999999848833293]

# %%
using PyPlot

num_rows, num_cols = 3,3
fig, ax = subplots(num_rows, num_cols, figsize=(9,9))
name = ["σ2_i", "B", "λ", "σ2_a", "σ2_s", "ϕ", "τ_ϕ", "bias", "lapse"]

for i in 1:9
                  
    map(x-> ax[i].plot(x[i,:]), traces)
    ax[i].set_title(name[i])
end

tight_layout()
# Out:
# Figure(PyObject <Figure size 900x900 with 9 Axes>)

# %%
using PyPlot

num_rows, num_cols = 3,3
fig, ax = subplots(num_rows, num_cols, figsize=(9,9))
name = ["σ2_i", "B", "λ", "σ2_a", "σ2_s", "ϕ", "τ_ϕ", "bias", "lapse"]

for i in 1:9
                  
    map(x-> ax[i].plot(x[i,:]), traces)
    ax[i].set_title(name[i])
end

tight_layout()
# Out:
# Figure(PyObject <Figure size 900x900 with 9 Axes>)
